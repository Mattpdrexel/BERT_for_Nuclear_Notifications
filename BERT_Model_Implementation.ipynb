# %%
"""Transformers Test (working, with improvements).ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1vwQneJX92WYgVynrmhDm9RINVzKDtSwa
"""
# Out:
# 'Transformers Test (working, with improvements).ipynb\n\nAutomatically generated by Colab.\n\nOriginal file is located at\n    https://colab.research.google.com/drive/1vwQneJX92WYgVynrmhDm9RINVzKDtSwa\n'

# %%
# Install required packages
# !pip install transformers scikit-learn nltk sentence-transformers

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.3.1+cu121)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.5.82)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from transformers import BertTokenizerFast, BertForQuestionAnswering, Trainer, TrainingArguments
from sentence_transformers import SentenceTransformer, util
import torch

# %%
# Configure the device
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Load the data from Excel
# Original data

folder_path = '/content/drive/My Drive/Additional Education/NJIT/Classes/DS677-850 Deep Learning/Project/Work Data'

# Synthetic data
synthetic_data_file_path = f'{folder_path}/labeled_synthetic_data (specific questions and answers).xlsx'

data = pd.read_excel(synthetic_data_file_path)

# Parse dates in 'CreatedOn' column
# data['CreatedOn'] = pd.to_datetime(data['CreatedOn'], format='%m/%d/%Y')

# %%
data.dropna(subset=['LongText'], how='all', inplace=True)

# %%
data
# Out:
#      Unnamed: 0   CreatedOn  Notification  OrderNum  \
# 0             0  2019-03-15      30761040  90231415
# 1             1  2020-11-18      30958076  80230196
# 2             2  2018-09-15      30751256  80212345
# 3             3  2019-11-17      30958230  80523058
# 4             4  2016-09-15      30751904  80225619
# ..          ...         ...           ...       ...
# 477         477  2018-12-27      40732176  90234712
# 478         478  2020-12-12      30991234  80298250
# 479         479  2019-04-30      30987450  80239876
# 480         480  2021-09-15      30985240  80589752
# 481         481  2019-04-28      30920832  80287345
#
#                                 ShortText              FLOC  \
# 0    Abrupt decrease in 18B Pump pressure       S4CW -4CWE7
# 1        Reduced output from 5B Generator  S5GN -5GNE2-GENR
# 2      Rapid frequency change in Pump 18A       S4CW -4CWE5
# 3        Unusual noise from 3B Pump motor       S5CW -5CWE2
# 4                        Fuse M87 tripped     S4EL -4EL1746
# ..                                    ...               ...
# 477           Overheating in Converter G4   S4AC -4ACE7-TG4
# 478        18A Motor Overheating observed       S4CW -4CWE2
# 479       Unusual vibration in 18B Blower       S5BL -3BLE6
# 480          Abnormal vibration in Fan 5A       S5AI -5AIE3
# 481   29B Pump unusual vibration detected       S1CW -1CWE5
#
#                                               LongText  \
# 0    * **************Incident Description**********...
# 1    * **************Incident Description**********...
# 2    * **************Incident Description**********...
# 3    * **************Incident Description**********...
# 4    * **************Incident Description**********...
# ..                                                 ...
# 477  * **************Incident Description**********...
# 478  * **************Incident Description**********...
# 479  * **************Incident Description**********...
# 480  * **************Incident Description**********...
# 481  * **************Incident Description**********...
#
#                                               Question  \
# 0    What immediate actions were recommended follow...
# 1    What was found as the cause of reduced perform...
# 2    What was the immediate action recommended afte...
# 3    What was the immediate action recommended afte...
# 4    What was the result of the electrical analysis...
# ..                                                 ...
# 477  What was the initial response to the overheati...
# 478  What were the immediate actions and recommende...
# 479  What measures were taken to correct the issue ...
# 480  What was the cause of the abnormal vibrations ...
# 481  What actions were recommended upon identifying...
#
#                                                 Answer
# 0    Isolate 18B Pump and investigate for internal ...
# 1    The advanced diagnostics found loose connectio...
# 2    Immediate action is to isolate and shut down p...
# 3    Inspect filtration systems and remove blockage...
# 4    The electrical analysis of M87 circuit was con...
# ..                                                 ...
# 477  Emergency protocol S4.OP-AB.AC-0002 was initia...
# 478  Immediate inspection and necessary maintenance...
# 479  Blower has been inspected and the misalignment...
# 480  The abnormal vibrations were due to a misalign...
# 481  Immediate shutdown of the 29B pump and mainten...
#
# [482 rows x 9 columns]

# %%
data["LongText"]
# Out:
# 0      * **************Incident Description**********...
# 1      * **************Incident Description**********...
# 2      * **************Incident Description**********...
# 3      * **************Incident Description**********...
# 4      * **************Incident Description**********...
#                              ...
# 477    * **************Incident Description**********...
# 478    * **************Incident Description**********...
# 479    * **************Incident Description**********...
# 480    * **************Incident Description**********...
# 481    * **************Incident Description**********...
# Name: LongText, Length: 482, dtype: object

# %%
# Configure the device
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Path to the directory where the model and tokenizer are saved
model_path = "/content/drive/My Drive/Additional Education/NJIT/Classes/DS677-850 Deep Learning/Project/Work Data/fine_tuned_bert_model"

# Load the tokenizer/model from tuned model that was saved locally
tokenizer = BertTokenizerFast.from_pretrained(model_path)
model = BertForQuestionAnswering.from_pretrained(model_path)

# Alternatively load fresh pretrained model
#tokenizer = BertTokenizerFast.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
#model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

model.to(device)  # Ensure the model is on the correct device

# Load and prepare the context embedding model
embed_model = SentenceTransformer('all-MiniLM-L6-v2')
embed_model.to(device)  # Ensure the embedding model is on the correct device
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )

# %%
# Converts the question into an embedding space
# Then finds the entries with long text that has the highest coside similarity in this embedding space
# Pick the top k entries based on these embeddings

def find_relevant_context(question, df, top_k=3):
    """
    Uses semantic search to find the most relevant contexts.
    """
    question_embedding = embed_model.encode(question, convert_to_tensor=True).to(device)
    df['context_embeddings'] = df['LongText'].apply(lambda text: embed_model.encode(text, convert_to_tensor=True).to(device))
    similarities = [util.pytorch_cos_sim(question_embedding, emb).item() for emb in df['context_embeddings']]
    top_indices = sorted(range(len(similarities)), key=lambda i: similarities[i], reverse=True)[:top_k]
    return df.iloc[top_indices]

# %%
def answer_question(question, context):
    inputs = tokenizer.encode_plus(question, context, add_special_tokens=True, truncation=True, max_length=512, return_tensors="pt")
    inputs = {k: v.to(device) for k, v in inputs.items()}

    with torch.no_grad():
        outputs = model(**inputs)
        answer_start_scores, answer_end_scores = outputs.start_logits, outputs.end_logits

    answer_start = torch.argmax(answer_start_scores)
    answer_end = torch.argmax(answer_end_scores) + 1
    answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(inputs['input_ids'][0][answer_start:answer_end]))
    return answer.replace("[CLS]", "").replace("[SEP]", "").strip(), answer_start, answer_end, inputs['input_ids'][0]

# %% [markdown]
# # Clean way to show a processed record
# def process_questions(data, question):
#     """
#     Process all questions and produce formatted answers.
#     """
#     results = []
#     relevant_contexts = find_relevant_context(question, data)
#     for _, row in relevant_contexts.iterrows():
#         context = row['LongText']
#         notification_id = row['Notification']
#         short_text = row['ShortText']
#         created_on = row['CreatedOn']
#         answer = answer_question(question, context)
#         if not answer:
#             answer = "No specific answer found."
#         formatted_answer = f"Not. {notification_id}, {short_text} ({created_on}) - {answer}"
#         results.append(formatted_answer)
#     return results

# %%
def process_questions(data, question):
    results = []
    relevant_contexts = find_relevant_context(question, data)
    for _, row in relevant_contexts.iterrows():
        context = row['LongText']
        notification_id = row['Notification']
        short_text = row['ShortText']
        created_on = row['CreatedOn']
        answer, answer_start, answer_end, input_ids = answer_question(question, context)
        if not answer:
            answer = "No specific answer found."

        # Highlight the answer within the original context
        start_index = context.lower().find(answer.lower())
        end_index = start_index + len(answer)
        highlighted_context = context[:start_index] + f"\033[1;31m{context[start_index:end_index]}\033[0m" + context[end_index:]

        formatted_result = f"Notification: {notification_id}\nShort Text: {short_text}\nCreated On: {created_on}\nQuestion: {question}\nContext: {highlighted_context}\nAnswer: {answer}\n"
        results.append(formatted_result)
    return results

# %%
# Example question
question = "what is the cause of the high vibrations on the condenser pump?"
all_results = process_questions(data, question)
all_results
# Out:
# ["Notification: 30978512\nShort Text: Unexpected vibration in 34A pump\nCreated On: 2021-09-10\nQuestion: what is the cause of the high vibrations on the condenser pump?\nContext: * **************Incident Description************** * Notification 000030978512 Details * *********************************************************** * 09/10/2021 07:45:17 INCIDENT REPORT (INCIDENT REPORT) * Report submitted by: Emily Smith ENTITY\\INCIDENT: * * CONDITION DESCRIPTION/LOCATION (THE INAPPROPRIATE ACTION AND ITS NEGATIVE EFFECT/INCLUDE A DETAILED LOCATION DESCRIPTION): * While monitoring operations, abnormal vibrations were noted on  the 34A pump. Upon visual inspection, no visible factors like leaks or visible damage  were found that could cause such abnormality. Measurements taken showed an increase in vibration levels by 20% compared to normal operation. * * ACTIVITIES, PROCESSES, PROCEDURES INVOLVED: * Vibration monitoring of operating pumps, S4.OP.AB-CW-0012 *  * WHY DID CONDITION HAPPEN?: * The exact cause is unknown. The pump was serviced 6 months ago under work order 80238940. It is possible the balancing of the pump wasn't done properly. * * CONSEQUENCES: * Decreased pump efficiency, possible pump damage if the issue is not addressed timely. * * REQUIREMENTS IMPACTED: * Normal pump operation, can impact overall system performance * * ADVERSE PHYSICAL CONDITIONS: * Increased vibration levels in 34A pump than usual * * WHO WAS NOTIFIED: * Maintenance Supervisor, Engineering team * * KNOWLEDGEABLE INDIVIDUALS: * Jane Doe (Maintenance Supervisor), John Doe (Engineer) * * REPEAT OR SIMILAR CONDITION: * No, this is the first incidence of abnormal vibration in 34A pump * * IMMEDIATE ACTIONS AND RECOMMENDED ACTIONS: * Engineering team to investigate the vibration issue, perform dynamic balancing if necessary. Maintenance team to carry out inspection for possible physical anomalies. * 09/12/2021 10:54:28 EMILY SMITH (INCIDENT) * The abnormal vibration seems to have been caused by \x1bimbalance\x1b. The pump was dynamically balanced and vibration levels returned to normal. The function of 34A pump has been successfully restored.\nAnswer: imbalance\n",
#  'Notification: 30834213\nShort Text: Vibration observed in Condenser Pump E4\nCreated On: 2019-02-12\nQuestion: what is the cause of the high vibrations on the condenser pump?\nContext: * **************Incident Description************** * Notification 000030834213 Details * *********************************************************** * 02/12/2019 15:23:12 INCIDENT REPORT (INCIDENT REPORT) * Report submitted by: Lisa Parker ENTITY\\INCIDENT: * * CONDITION DESCRIPTION/LOCATION (THE INAPPROPRIATE ACTION AND ITS NEGATIVE EFFECT/INCLUDE A DETAILED LOCATION DESCRIPTION): * During a regular CW system inspection, a significant level of vibration  was observed in the E4 Condenser Pump. The vibration monitor was reading at  60 mm/s, which is higher than normal operational levels. * * ACTIVITIES, PROCESSES, PROCEDURES INVOLVED: * Regular CW system inspection. * * WHY DID CONDITION HAPPEN? * The root cause of the elevated vibration levels is currently not clear. However,  such incidents can be a result of operating conditions, or potential mechanical issues  like bearing damage or imbalance in the rotating parts. * * CONSEQUENCES: * High pump vibrations can lead to damage and reduced operational efficiency. Early detection helps in avoiding possible breakdowns. * * REQUIREMENTS IMPACTED: * Normal Operation * * ADVERSE PHYSICAL CONDITIONS: * Elevated vibration level from E4 Condenser Pump * * WHO WAS NOTIFIED: * The Maintenance Team, Operations Manager, System Engineer * * KNOWLEDGEABLE INDIVIDUALS: * Lisa Parker, System Engineer, Maintenance Team * * REPEAT OR SIMILAR CONDITION: * No, this is the first incident of noticeable vibration on E4 pump. * * IMMEDIATE ACTIONS AND RECOMMENDED ACTIONS: * The pump was shutdown for immediate inspection and maintenance. If necessary,  parts will be replaced or adjustments made to reduce the vibration.  * 02/13/2019 09:25:30 LISA PARKER (INCIDENT) * The inspection identified \x1bworn out bearings\x1b as the cause of the vibration.  Bearings have been replaced and pump has been reassembled and put back into operation. The vibration levels are now within acceptable limits.\nAnswer: worn out bearings\n',
#  'Notification: 30952736\nShort Text: 8B Condenser abnormal vibration\nCreated On: 2018-12-15\nQuestion: what is the cause of the high vibrations on the condenser pump?\nContext: * **************Incident Description************** * Notification 000030952736 Details * *********************************************************** * 12/15/2018 13:32:20 INCIDENT REPORT (INCIDENT REPORT) * Report submitted by: David Smith ENTITY\\INCIDENT: * * CONDITION DESCRIPTION/LOCATION (THE INAPPROPRIATE ACTION AND ITS NEGATIVE EFFECT/INCLUDE A DETAILED LOCATION DESCRIPTION): * During a scheduled inspection, 8B Condenser has been found to have an abnormal  vibration. The vibration amplitude and frequency have significantly increased  from the baseline levels. This increased vibration could be an indication of a  potential \x1bmechanical failure\x1b. * * ACTIVITIES, PROCEDURES, PROCESSES INVOLVED: * Scheduled inspection and vibration analysis. * * WHY DID CONDITION HAPPEN? * The exact reason is unknown at this time. It might be due to wear  or mechanical misalignment. * * CONSEQUENCES: * Possible machine damage, reduced efficiency and could result in an  unscheduled outage if not addressed timely. * * REQUIREMENTS IMPACTED: * Equipment reliability and operation. * * ADVERSE PHYSICAL CONDITIONS: * Abnormal vibrations from the 8B Condenser. * * WHO WAS NOTIFIED: * Operations Manager, Maintenance supervisor  * * KNOWLEDGEABLE INDIVIDUALS: * David Smith, Tom Johnson, Gary Wilson * * REPEAT OR SIMILAR CONDITION: * No * * IMMEDIATE ACTIONS AND RECOMMENDED ACTIONS: * An immediate investigation is initiated to pinpoint the root cause of  vibrations. Recommended initiating a work order for technical inspection  and performing an in-depth vibration analysis. * 12/17/2018 09:43:51 LIZA MILLER (INCIDENT) * An expert visit to inspect the unit has been arranged. The machine will be  kept under continuous observation till the issue gets resolved. Anticipate  resolution without any significant operational disruption.\nAnswer: mechanical failure\n']

# %%
for result in all_results:
    print(result)
# Out:
# Notification: 30978512
# Short Text: Unexpected vibration in 34A pump
# Created On: 2021-09-10
# Question: what is the cause of the high vibrations on the condenser pump?
# Context: * **************Incident Description************** * Notification 000030978512 Details * *********************************************************** * 09/10/2021 07:45:17 INCIDENT REPORT (INCIDENT REPORT) * Report submitted by: Emily Smith ENTITY\INCIDENT: * * CONDITION DESCRIPTION/LOCATION (THE INAPPROPRIATE ACTION AND ITS NEGATIVE EFFECT/INCLUDE A DETAILED LOCATION DESCRIPTION): * While monitoring operations, abnormal vibrations were noted on  the 34A pump. Upon visual inspection, no visible factors like leaks or visible damage  were found that could cause such abnormality. Measurements taken showed an increase in vibration levels by 20% compared to normal operation. * * ACTIVITIES, PROCESSES, PROCEDURES INVOLVED: * Vibration monitoring of operating pumps, S4.OP.AB-CW-0012 *  * WHY DID CONDITION HAPPEN?: * The exact cause is unknown. The pump was serviced 6 months ago under work order 80238940. It is possible the balancing of the pump wasn't done properly. * * CONSEQUENCES: * Decreased pump efficiency, possible pump damage if the issue is not addressed timely. * * REQUIREMENTS IMPACTED: * Normal pump operation, can impact overall system performance * * ADVERSE PHYSICAL CONDITIONS: * Increased vibration levels in 34A pump than usual * * WHO WAS NOTIFIED: * Maintenance Supervisor, Engineering team * * KNOWLEDGEABLE INDIVIDUALS: * Jane Doe (Maintenance Supervisor), John Doe (Engineer) * * REPEAT OR SIMILAR CONDITION: * No, this is the first incidence of abnormal vibration in 34A pump * * IMMEDIATE ACTIONS AND RECOMMENDED ACTIONS: * Engineering team to investigate the vibration issue, perform dynamic balancing if necessary. Maintenance team to carry out inspection for possible physical anomalies. * 09/12/2021 10:54:28 EMILY SMITH (INCIDENT) * The abnormal vibration seems to have been caused by imbalance. The pump was dynamically balanced and vibration levels returned to normal. The function of 34A pump has been successfully restored.
# Answer: imbalance
#
# Notification: 30834213
# Short Text: Vibration observed in Condenser Pump E4
# Created On: 2019-02-12
# Question: what is the cause of the high vibrations on the condenser pump?
# Context: * **************Incident Description************** * Notification 000030834213 Details * *********************************************************** * 02/12/2019 15:23:12 INCIDENT REPORT (INCIDENT REPORT) * Report submitted by: Lisa Parker ENTITY\INCIDENT: * * CONDITION DESCRIPTION/LOCATION (THE INAPPROPRIATE ACTION AND ITS NEGATIVE EFFECT/INCLUDE A DETAILED LOCATION DESCRIPTION): * During a regular CW system inspection, a significant level of vibration  was observed in the E4 Condenser Pump. The vibration monitor was reading at  60 mm/s, which is higher than normal operational levels. * * ACTIVITIES, PROCESSES, PROCEDURES INVOLVED: * Regular CW system inspection. * * WHY DID CONDITION HAPPEN? * The root cause of the elevated vibration levels is currently not clear. However,  such incidents can be a result of operating conditions, or potential mechanical issues  like bearing damage or imbalance in the rotating parts. * * CONSEQUENCES: * High pump vibrations can lead to damage and reduced operational efficiency. Early detection helps in avoiding possible breakdowns. * * REQUIREMENTS IMPACTED: * Normal Operation * * ADVERSE PHYSICAL CONDITIONS: * Elevated vibration level from E4 Condenser Pump * * WHO WAS NOTIFIED: * The Maintenance Team, Operations Manager, System Engineer * * KNOWLEDGEABLE INDIVIDUALS: * Lisa Parker, System Engineer, Maintenance Team * * REPEAT OR SIMILAR CONDITION: * No, this is the first incident of noticeable vibration on E4 pump. * * IMMEDIATE ACTIONS AND RECOMMENDED ACTIONS: * The pump was shutdown for immediate inspection and maintenance. If necessary,  parts will be replaced or adjustments made to reduce the vibration.  * 02/13/2019 09:25:30 LISA PARKER (INCIDENT) * The inspection identified worn out bearings as the cause of the vibration.  Bearings have been replaced and pump has been reassembled and put back into operation. The vibration levels are now within acceptable limits.
# Answer: worn out bearings
#
# Notification: 30952736
# Short Text: 8B Condenser abnormal vibration
# Created On: 2018-12-15
# Question: what is the cause of the high vibrations on the condenser pump?
# Context: * **************Incident Description************** * Notification 000030952736 Details * *********************************************************** * 12/15/2018 13:32:20 INCIDENT REPORT (INCIDENT REPORT) * Report submitted by: David Smith ENTITY\INCIDENT: * * CONDITION DESCRIPTION/LOCATION (THE INAPPROPRIATE ACTION AND ITS NEGATIVE EFFECT/INCLUDE A DETAILED LOCATION DESCRIPTION): * During a scheduled inspection, 8B Condenser has been found to have an abnormal  vibration. The vibration amplitude and frequency have significantly increased  from the baseline levels. This increased vibration could be an indication of a  potential mechanical failure. * * ACTIVITIES, PROCEDURES, PROCESSES INVOLVED: * Scheduled inspection and vibration analysis. * * WHY DID CONDITION HAPPEN? * The exact reason is unknown at this time. It might be due to wear  or mechanical misalignment. * * CONSEQUENCES: * Possible machine damage, reduced efficiency and could result in an  unscheduled outage if not addressed timely. * * REQUIREMENTS IMPACTED: * Equipment reliability and operation. * * ADVERSE PHYSICAL CONDITIONS: * Abnormal vibrations from the 8B Condenser. * * WHO WAS NOTIFIED: * Operations Manager, Maintenance supervisor  * * KNOWLEDGEABLE INDIVIDUALS: * David Smith, Tom Johnson, Gary Wilson * * REPEAT OR SIMILAR CONDITION: * No * * IMMEDIATE ACTIONS AND RECOMMENDED ACTIONS: * An immediate investigation is initiated to pinpoint the root cause of  vibrations. Recommended initiating a work order for technical inspection  and performing an in-depth vibration analysis. * 12/17/2018 09:43:51 LIZA MILLER (INCIDENT) * An expert visit to inspect the unit has been arranged. The machine will be  kept under continuous observation till the issue gets resolved. Anticipate  resolution without any significant operational disruption.
# Answer: mechanical failure
